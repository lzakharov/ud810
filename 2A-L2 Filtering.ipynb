# %% [markdown]
# # 2A-L2 Filtering

# %% [markdown]
# ## Remove Noise

# %% [markdown]
# ### Load image

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

img = cv2.imread('./images/saturn.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray');

# %% [markdown]
# ### Add some noise

# %%
noise_sigma = 25
noise = np.random.randn(*img.shape) * noise_sigma
img_noisy = img + noise
plt.imshow(img_noisy, cmap='gray');

# %% [markdown]
# ### Apply a Gaussian filter

# %%
from scipy.ndimage import gaussian_filter

smoothed = gaussian_filter(img_noisy, sigma=2)
plt.imshow(smoothed, cmap='gray');
